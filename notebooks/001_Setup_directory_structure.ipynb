# %% [markdown]
# # Setup directory structure
#
# As you cannot git push empty folders, some of them must be recreated manually.

# %% [markdown]
# ```
# On MacOS:
# brew install tree
# ```

# %% [markdown]
# ```
# tree -L 3 --dirsfirst
# .
# ├── data
# │   ├── artifacts
# │   ├── custom_models
# │   ├── data_pipeline
# │   │   ├── raw
# │   │   ├── staging
# │   │   └── training
# │   ├── db
# │   ├── performance_monitoring
# │   │   └── input
# │   ├── training_pipeline
# │   │   └── predictions
# │   └── training_dataset.csv
# ├── docker
# │   ├── jupyter
# │   │   ├── scripts
# │   │   ├── Dockerfile
# │   │   └── requirements.test.txt
# │   ├── mlflow
# │   │   ├── scripts
# │   │   └── Dockerfile
# │   ├── postgres
# │   │   ├── Dockerfile
# │   │   └── init.sql
# │   └── python-dev
# │       ├── Dockerfile
# │       ├── Dockerfile.dockerignore
# │       └── requirements.txt
# ├── notebooks
# │   ├── img
# │   │   ├── btc-usd.png
# │   │   ├── feast-marchitecture-211014.png
# │   │   ├── mlops_experimentation.png
# │   │   ├── mlops_lifecycle.png
# │   │   ├── mlops_prediction_serving_and_monitoring.png
# │   │   └── mlops_training_data_pipeline.png
# │   ├── 001_Setup_directory_structure.ipynb
# │   ├── 005_EXP_Problem_definition.ipynb
# │   ├── 006_EXP_Experiment_init.ipynb
# │   ├── 010_EXP_EDA_and_data_preparation.ipynb
# │   ├── 100_EXP_Predictor_random.ipynb
# │   ├── 110_EXP_Predictor_logistic_regression.ipynb
# │   ├── 120_EXP_Predictor_xgboost.ipynb
# │   ├── 130_EXP_Predictor_keras.ipynb
# │   ├── 140_EXP_Hyperparameter_optimization.ipynb
# │   ├── 150_Model_Registration.ipynb
# │   ├── 220_Training_data_pipeline.ipynb
# │   ├── 240_Model_training_pipeline.ipynb
# │   ├── 280_Inference_from_ds_workbench.ipynb
# │   ├── 290_Inference_from_Docker.ipynb
# │   ├── 300_Performance_monitoring.ipynb
# │   ├── 400_AutoML.ipynb
# │   ├── 500_MLflow_Plugins.ipynb
# │   └── not_ready_200_Feature_Store.ipynb
# ├── src
# │   ├── __pycache__
# │   │   ├── config.cpython-37.pyc
# │   │   ├── config.cpython-38.pyc
# │   │   ├── config.cpython-39.pyc
# │   │   ├── data_utils.cpython-37.pyc
# │   │   └── data_utils.cpython-39.pyc
# │   ├── workbench
# │   │   └── __init__.py
# │   ├── __init__.py
# │   ├── config.py
# │   └── data_utils.py
# ├── tests
# │   ├── docker
# │   │   ├── __init__.py
# │   │   └── test_mlflow.py
# │   ├── python
# │   │   ├── __init__.py
# │   │   └── test_version.py
# │   └── run_docker_tests.sh
# ├── Makefile
# ├── README.md
# ├── docker-compose.yml
# ├── notes.txt
# ├── requirements.txt
# ├── setup.py
# └── tox.ini
# ```
